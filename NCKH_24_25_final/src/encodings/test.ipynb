# %%
import pickle
from pprint import pprint  # dùng để in đẹp hơn

# Đường dẫn tới file pkl
file_path = 'encodings.pkl'

try:
    with open(file_path, 'rb') as file:
        data = pickle.load(file)
        
        print("Đọc file thành công.")
        print("Nội dung đầy đủ:")
        pprint(data)  # in đẹp và đầy đủ nội dung

except FileNotFoundError:
    print("Không tìm thấy file:", file_path)
except Exception as e:
    print("Có lỗi khi đọc file:", e)
# Out:
# ✅ Đọc file thành công.
# 📦 Nội dung đầy đủ:
# {'002_TrinhVanManh': array([ 0.091268  , -0.0536201 , -0.11336225,  0.04876249, -0.0310666 ,
#         0.02815469,  0.01119954, -0.11087818,  0.03219812, -0.00316531,
#        -0.17082998,  0.04716278, -0.0334767 , -0.13626689,  0.00024189,
#         0.0205374 ,  0.06574742, -0.02358017,  0.06389285, -0.00890023,
#        -0.10725405,  0.05236791, -0.17268775,  0.02121952, -0.05049219,
#         0.07039793,  0.0012555 ,  0.06344946, -0.01727612,  0.0404699 ,
#         0.16122705,  0.0542372 , -0.00808052, -0.06240678, -0.04296975,
#        -0.0662953 , -0.12229033, -0.09377094,  0.12789288, -0.05938155,
#        -0.06616603,  0.03933852, -0.07400941, -0.06973023,  0.03452444,
#         0.04794034,  0.06826369,  0.06654584, -0.19573477,  0.15887336,
#         0.00598523, -0.01621868,  0.01104581,  0.02414253,  0.1207917 ,
#         0.01598177, -0.07330129, -0.04873107,  0.05711101, -0.06596772,
# ...
