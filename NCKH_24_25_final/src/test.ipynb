# %%
import h5py

with h5py.File('facenet_keras_weights.h5', 'r') as f:
    def print_attrs(name, obj):
        print(name)
        for key, val in obj.attrs.items():
            print(f"  {key}: {val}")

    f.visititems(print_attrs)
# Out:
# AvgPool
#   weight_names: []
# Block17_10_Activation
#   weight_names: []
# Block17_10_Branch_0_Conv2d_1x1
#   weight_names: [b'Block17_10_Branch_0_Conv2d_1x1/kernel:0']
# Block17_10_Branch_0_Conv2d_1x1/Block17_10_Branch_0_Conv2d_1x1
# Block17_10_Branch_0_Conv2d_1x1/Block17_10_Branch_0_Conv2d_1x1/kernel:0
# Block17_10_Branch_0_Conv2d_1x1_Activation
#   weight_names: []
# Block17_10_Branch_0_Conv2d_1x1_BatchNorm
#   weight_names: [b'Block17_10_Branch_0_Conv2d_1x1_BatchNorm/beta:0'
#  b'Block17_10_Branch_0_Conv2d_1x1_BatchNorm/moving_mean:0'
#  b'Block17_10_Branch_0_Conv2d_1x1_BatchNorm/moving_variance:0']
# Block17_10_Branch_0_Conv2d_1x1_BatchNorm/Block17_10_Branch_0_Conv2d_1x1_BatchNorm
# Block17_10_Branch_0_Conv2d_1x1_BatchNorm/Block17_10_Branch_0_Conv2d_1x1_BatchNorm/beta:0
# Block17_10_Branch_0_Conv2d_1x1_BatchNorm/Block17_10_Branch_0_Conv2d_1x1_BatchNorm/moving_mean:0
# Block17_10_Branch_0_Conv2d_1x1_BatchNorm/Block17_10_Branch_0_Conv2d_1x1_BatchNorm/moving_variance:0
# ...
